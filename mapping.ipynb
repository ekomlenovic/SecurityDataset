# %%
import pandas as pd
import networkx as nx
import numpy as np
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import networkx as nx
#       3 import numpy as np
# ----> 4 from mpl_toolkits.basemap import Basemap
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
file1 = 'data/db_preprocessed.csv'
df = pd.read_csv(file1)
pd.set_option('display.max_columns', None)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 file1 = 'data/db_preprocessed.csv'
# ----> 2 df = pd.read_csv(file1)
#       3 pd.set_option('display.max_columns', None)
#       4 df.head()
#
# NameError: name 'pd' is not defined

# %%
def graph_from_dataframe(dataframe) -> nx.Graph:
    G = nx.Graph()
    G.add_nodes_from((eventid, {'label': 'eventid', 'longitude': lon, 'latitude': lat}) for eventid, lon, lat in zip(dataframe['eventid'], dataframe['longitude'], dataframe['latitude']))
    return G

# %%
df_copy = df.copy()

G = graph_from_dataframe(df_copy)

positions = dict(zip(G.nodes, [(df['longitude'], df['latitude'])]))

df_copy.loc[df['longitude'].isnull(), 'longitude'] = 0
df_copy.loc[df['latitude'].isnull(), 'latitude'] = 0

# %%
def plot_terrorism_map(graph, dataframe, filepath="plot.png"):
    basemap = Basemap(
        projection='merc',
        llcrnrlat=-80,
        urcrnrlat=80,
        llcrnrlon=-180,
        urcrnrlon=180,
        lat_ts=20,
        resolution='c'
    )

    mapX, mapY = basemap(dataframe['longitude'].values, dataframe['latitude'].values)

    coordinates = np.column_stack((mapX, mapY))

    positions = dict(zip(graph.nodes, coordinates))

    nx.draw_networkx(graph, positions, with_labels=False, node_size=1, node_color='red',alpha=0.3 )
    basemap.drawcountries()
    basemap.drawstates()
    basemap.bluemarble()

    plt.savefig(filepath, dpi=1000)

plot_terrorism_map(G, df.copy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
mini_df = df_copy.copy().head(1)
mini_graph = graph_from_dataframe(mini_df)

mini_df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  202101010004   2021       1     1        NaN         0        NaT       60
#
#   country_txt  region                  region_txt    provstate         city  \
# 0       Egypt      10  Middle East & North Africa  North Sinai  Beir al-Abd
#
#     latitude  longitude  specificity  vicinity location  \
# 0  31.016779  33.008587            1         0      NaN
#
#                                              summary  crit1  crit2  crit3  \
# 0  01/01/2021: An explosive device detonated targ...      1      1      0
#
#    doubtterr  alternative             alternative_txt  multiple  success  \
# 0          1          1.0  Insurgency/Guerilla Action       0.0        1
#
#    suicide  attacktype1    attacktype1_txt  attacktype2 attacktype2_txt  \
# 0        0            3  Bombing/Explosion          NaN             NaN
#
#    attacktype3 attacktype3_txt  targtype1 targtype1_txt  targsubtype1  \
# ...

# %%
plot_terrorism_map(mini_graph,mini_df,filepath="mini.png")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
file2 = 'data\globalterrorismdb_0522dist.xlsx'
df_2 = pd.read_excel(file2)

df_2.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaT       58
# 1  197000000002   1970       0     0        NaN         0        NaT      130
# 2  197001000001   1970       1     0        NaN         0        NaT      160
# 3  197001000002   1970       1     0        NaN         0        NaT       78
# 4  197001000003   1970       1     0        NaN         0        NaT      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean  National
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df2_copy = df_2.copy()
positions = dict(zip(G.nodes, [(df_2['longitude'], df_2['latitude'])]))

df2_copy.loc[df_2['longitude'].isnull(), 'longitude'] = 0
df2_copy.loc[df_2['latitude'].isnull(), 'latitude'] = 0

df2_copy.size
# Out:
# 28310310

# %%
graph2 = graph_from_dataframe(df2_copy)

plot_terrorism_map(graph2,df2_copy,filepath="plot2.png")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
df2_copy = df2_copy.loc[df2_copy['success'] == True]

print(df2_copy.size)

graph2 = graph_from_dataframe(df2_copy)

plot_terrorism_map(graph2,df2_copy,filepath="plot2.png")
# Out:
# 25015770
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
